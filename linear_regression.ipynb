# %%
from sklearn.datasets import load_boston
dataset = load_boston()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dataset['data'], dataset['target'], test_size = 0.2)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler() 
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

# %%
from sklearn import linear_model
linear = linear_model.LinearRegression()
linear.fit(X_train_std, y_train)
# Out:
# LinearRegression()

# %%
y_pred = linear.predict(X_test_std)
print("Pred:", y_pred) 
print("True:", y_test)
# Out:
# Pred: [19.65127377 17.53276751 25.72031368 20.3014422  24.37003189 34.62904176
#  22.33284489 23.57237341 26.39508383 24.99758995 16.08637452 13.54185067
#  19.3343637  23.767977   37.33320838 19.08440465 37.21992536 21.05054626
#  31.11453427 28.14635291 28.0104943  13.3852416  24.85137249 24.86998819
#  22.47466575  7.97240304 18.83517223 20.48717514 28.2069332  27.10047029
#  16.75834855 24.24268772 16.98453385 26.94556303 20.72660053 16.13774147
#  18.73897167 28.0504233  31.46672663 15.86304476 22.46271829 17.34167895
#  22.4198433  24.64398835 20.78600205 -5.02249924 18.17423207 18.068847
#  30.43238127 18.88457277 24.0649951  24.8357531  17.34798036 23.72494497
#  21.74779378 21.99158293 10.07498032 16.24292694 21.95242515 33.36927403
#  20.21308375  8.93003282 26.89654603 12.11752042 28.56428145 19.27437024
#  18.50206311 17.65562873 27.24828905 29.01739854 13.1087707  23.20678438
#  34.12646674 20.0422268  21.13206042 14.01822317 19.25720269 32.72434218
#  21.54895652 14.14976431 26.54058459 25.85442049 13.15039636 22.63734256
#  27.2133803  24.0553073  23.16362649 19.53378453 20.49751701 35.8266682
#  21.97612443  7.09814614 12.73222799 23.99200573 22.84759048 19.29573387
#  16.22073763 14.25898423 26.04786418 17.03728155 15.47132929 27.83673313]
# True: [12.5 23.2 23.2 19.2 24.6 34.9 33.  22.2 24.8 21.5 20.6 14.5 24.3 20.3
#  48.3 20.8 50.  18.7 28.4 28.7 23.9 13.5 23.1 24.2 20.   7.2 14.1 17.7
#  23.3 23.9 17.5 19.2 19.3 22.6 13.1 11.7 27.1 36.2 31.5 17.5 17.  18.1
#  21.2 24.8 16.8  7.  19.6 19.9 30.5 20.1 30.1 22.7 22.5 24.4 25.  16.1
#  23.7 13.3 22.5 36.1 19.4 17.8 22.3 16.3 22.8 20.5 18.2 15.1 22.1 28.4
#  13.9 25.  35.4 19.5 23.3 17.2 19.9 27.5 22.2 10.4 22.  15.  13.4 17.8
#  24.5 18.9 21.  17.1 23.1 35.2 16.5  8.5 10.5 21.4 26.4 19.9 18.6 11.
#  20.7 17.4 15.6 26.6]

# %%
from sklearn.metrics import mean_squared_error
print('MSE:', mean_squared_error(y_pred, y_test))
# Out:
# MSE: 19.786172395562147

# %%
import matplotlib.pyplot as plt
fig = plt.figure( figsize=(8,8))
plt.scatter(X_test[:,-1], y_test, label='y_test')  
plt.scatter(X_test[:,-1], y_pred, c='r', label='y_pred')  
plt.legend(loc='best')  
plt.show()
